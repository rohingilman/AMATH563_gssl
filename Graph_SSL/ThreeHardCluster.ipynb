# %% [markdown]
# # Hard Three Cluster

# %%
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx

from numpy.random import multivariate_normal as mvn

from scipy.stats import norm
from scipy.optimize import minimize

from math import floor
from math import log

from KNN import KNN
from KNN import proximity


from accuracy import KNN_acc
from accuracy import Prox_acc

from tqdm import tqdm

# %% [markdown]
# ## Generate Points

# %% [markdown]
# Generate X values

# %%
m = 300 # Number of samples (MAKE THIS A MULTIPLE OF 3)

knownvals = [int(j*m/3) for j in range(3)] # Points for which we know the value of the label

centers = [[0,0],[1,0],[1,1]]
covar = 0.1*np.identity(2)

X = mvn(centers[0],covar, int(m/3))
X = np.append(X,mvn(centers[1],covar, int(m/3)), axis=0)
X = np.append(X,mvn(centers[2],covar, int(m/3)), axis=0)

# %% [markdown]
# Generate y values

# %%
y = [1 for i in range(int(m/3))]
y = y + [-1 for i in range(m - len(y))]

# %% [markdown]
# Plot points with labels

# %%
xs = X[:,0]
ys = X[:,1]

plt.scatter(xs, ys, c=y, cmap = "viridis")

# %% [markdown]
# ## Build the Graph

# %%
k = 10
rbf = lambda x1, x2: np.exp(-0.5*np.linalg.norm(x1 - x2)**2)

L, W = KNN(X,k,m,rbf)

# %% [markdown]
# Making plot with edges

# %%
xs = X[:,0]
ys = X[:,1]

xs_k = [xs[j] for j in knownvals]
ys_k = [ys[j] for j in knownvals]

plt.scatter(xs, ys)
plt.scatter(xs_k, ys_k, color="red")

for i in range(m):
	for j in range(i,m):
		if W[i,j] > 0:
			plt.plot([X[i,0],X[j,0]],[X[i,1],X[j,1]], color = "gray", zorder = 0)

# %% [markdown]
# ## Form Optimization Problem

# %% [markdown]
# Define loss function

# %%
def probit(kvals, y, f):
	return -sum([log(norm.cdf(y[j]*f[j])) for j in kvals])

# %% [markdown]
# Define regularization

# %%
def regular(lamb,C_inv,f):
    f_T = np.array(f).T
    return lamb*f_T.dot(C_inv).dot(f)

# %%
tau = 1
alpha: int = 2
lamb = (tau**(2*alpha))/2
C = np.linalg.matrix_power(((L + (tau**2)*np.eye(m))),-alpha)
C_inv = np.linalg.inv(C)

# %% [markdown]
# Going to minimization

# %%
def to_minimize(f,kvals,y,lamb,C_inv):
    return probit(kvals,y,f) + regular(lamb,C_inv,f)

# %%
f0 = np.zeros(m)

result = minimize(to_minimize, f0, args=(knownvals,y,lamb,C_inv), method='BFGS')

# %%
f_star = result.x

y_pred = np.sign(f_star)

# %%
xs = X[:,0]
ys = X[:,1]

xs_k = [xs[j] for j in knownvals]
ys_k = [ys[j] for j in knownvals]

plt.scatter(xs, ys, c=y_pred, cmap = "viridis")
plt.scatter(xs_k, ys_k, color="red")

# %% [markdown]
# ## Compute Accuracy

# %%
accuracy = sum([x[0] == x[1] for x in zip(y_pred,y)])/m
print(accuracy)
# Out:
# 0.8566666666666667

# %% [markdown]
# ## Do it a bunch

# %% [markdown]
# ### Do it with KNN

# %% [markdown]
# Probit Loss

# %%
num_trials = 50

accs = []

rbf = lambda x1, x2: np.exp(-0.5*np.linalg.norm(x1 - x2)**2)

for i in tqdm(range(num_trials)):
	m = 102 # Number of samples (MAKE THIS A MULTIPLE OF 3)

	knownvals = [int(j*m/3) for j in range(3)] # Points for which we know the value of the label

	centers = [[0,0],[1,0],[1,1]]
	covar = 0.01*np.identity(2)

	X = mvn(centers[0],covar, int(m/3))
	X = np.append(X,mvn(centers[1],covar, int(m/3)), axis=0)
	X = np.append(X,mvn(centers[2],covar, int(m/3)), axis=0)

	y = [1 for i in range(int(m/3))]
	y = y + [-1 for i in range(m - len(y))]

	accs += [KNN_acc(X, y, knownvals, alpha = 2, tau = 1, lossf = "probit", k = 4, kernel= rbf)]

# %%
print(sum(accs)/50)

# %% [markdown]
# Regression loss

# %%
num_trials = 50

accs = []

rbf = lambda x1, x2: np.exp(-0.5*np.linalg.norm(x1 - x2)**2)

for i in tqdm(range(num_trials)):
	m = 102 # Number of samples (MAKE THIS A MULTIPLE OF 3)

	knownvals = [int(j*m/3) for j in range(3)] # Points for which we know the value of the label

	centers = [[0,0],[1,0],[1,1]]
	covar = 0.01*np.identity(2)

	X = mvn(centers[0],covar, int(m/3))
	X = np.append(X,mvn(centers[1],covar, int(m/3)), axis=0)
	X = np.append(X,mvn(centers[2],covar, int(m/3)), axis=0)

	y = [1 for i in range(int(m/3))]
	y = y + [-1 for i in range(m - len(y))]

	accs += [KNN_acc(X, y, knownvals, alpha = 2, tau = 1, lossf = "regression", k = 4, kernel= rbf)]

# %%
print(sum(accs)/50)

# %% [markdown]
# Do it with Proximity

# %%
num_trials = 50

accs = []

rbf = lambda x1, x2: np.exp(-0.5*np.linalg.norm(x1 - x2)**2)

for i in tqdm(range(num_trials)):
	m = 102 # Number of samples (MAKE THIS A MULTIPLE OF 3)

	knownvals = [int(j*m/3) for j in range(3)] # Points for which we know the value of the label

	centers = [[0,0],[1,0],[1,1]]
	covar = 0.01*np.identity(2)

	X = mvn(centers[0],covar, int(m/3))
	X = np.append(X,mvn(centers[1],covar, int(m/3)), axis=0)
	X = np.append(X,mvn(centers[2],covar, int(m/3)), axis=0)

	y = [1 for i in range(int(m/3))]
	y = y + [-1 for i in range(m - len(y))]

	accs += [Prox_acc(X, y, knownvals, alpha = 2, tau = 1, lossf = "probit", kernel= rbf)]
# Out:
# 100%|██████████| 50/50 [06:15<00:00,  7.52s/it]

# %%
print(sum(accs)/50)
# Out:
# 0.666666666666667
