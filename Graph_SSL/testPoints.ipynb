# %%
from points import spiralPoints

import matplotlib.pyplot as plt
import numpy as np

from math import pi

# %%
pts = spiralPoints(1000,0,4*pi)

# %%
xs = pts[:,0]
ys = pts[:,1]

# %%
plt.scatter(xs,ys)

# %%
covar = 0.1*np.identity(2)
mu = [0,0]

# %%
pts = np.random.multivariate_normal(mu,covar,1000)

# %%
xs = pts[:,0]
ys = pts[:,1]

# %%
plt.scatter(xs,ys)
